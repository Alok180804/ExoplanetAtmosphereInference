# %% [markdown]
# <a href="https://colab.research.google.com/github/Alok180804/OrbitalStatbility/blob/main/LiterartureRivew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🌌 A. Astrophysics & Orbital Dynamics (Domain Knowledge)
# 1. Exoplanetary Systems Basics
# Topics to Study:
#
# What are exoplanets?
#
# Exoplanet detection methods: Transit, Radial velocity, Direct imaging
#
# How planetary parameters (mass, radius, orbital period) are derived
#
# Overview of Kepler-90 system: focus on planets g, h, i
#
# Why orbital stability matters in multi-planet systems
#
# Resources:
#
# 📘 Exoplanet Handbook by Michael Perryman (Ch. 2–3, 7)
#
# 📄 NASA Exoplanet Archive – Kepler-90 system
#
# 🌐 NASA’s Exoplanet Exploration
#
#
# 2. Orbital Mechanics
# Topics to Study:
#
# Newton's law of gravitation, two-body vs N-body systems
#
# Orbital elements: semi-major axis, eccentricity, inclination, etc.
#
# Perturbations, resonance (2:1, 3:2), and chaos in multi-planet dynamics
#
# Conservation laws (energy, momentum)
#
# Resources:
#
# 📘 Fundamentals of Astrodynamics by Bate, Mueller, and White
#
# 📘 Solar System Dynamics by Murray & Dermott (Ch. 1–3, 6, 8)
#
# 🧠 MIT OCW – Classical Mechanics (Walter Lewin)
#
# ---------------------------------------------------------------------------
#
# 💻 B. Computational Simulation & Tools
# 1. N-body Simulation with REBOUND
# Topics to Study:
#
# Setting up N-body simulations
#
# Using integrators: IAS15 (adaptive), WHFast (symplectic)
#
# Adding/removing bodies, defining initial conditions
#
# Interpreting simulation output (positions, orbital elements)
#
# Resources:
#
# 🛠 REBOUND Official Docs & Tutorials
#
# 🧪 Hanno Rein’s YouTube – REBOUND Tutorials
#
# 📄 Rein & Liu (2012) paper: REBOUND: an open-source N-body integrator
#
# 2. Python Scientific Libraries
# Key Libraries:
#
# NumPy – numerical arrays, vectorized computation
#
# Matplotlib – plotting orbital data, time-series
#
# AstroPy – units, time conversion, astronomical calculations
#
# Pandas – manipulating simulation data tables
#
# Resources:
#
# 📘 Python Data Science Handbook by Jake VanderPlas
#
# 🧑‍💻 AstroPy Documentation
#
# 📘 Automate the Boring Stuff (for Python beginners)
#
# ---------------------------------------------------------------------------
#
# 🤖 C. Machine Learning & Time-Series Modeling
# 1. ML Basics
# Topics to Study:
#
# Supervised learning: classification vs regression
#
# Data preprocessing, normalization
#
# Evaluation metrics: accuracy, F1-score, confusion matrix
#
# Resources:
#
# 📘 Hands-On ML with Scikit-Learn, Keras & TensorFlow by Aurélien Géron
#
# 🎓 Google ML Crash Course (free)
#
# 🧑‍💻 Scikit-learn Documentation
#
# 2. Modeling Time-Series Data
# Topics to Study:
#
# Basics of time-series modeling: trend, seasonality
#
# LSTM (Long Short-Term Memory) networks for sequence prediction
#
# Feature engineering from orbital data (mean eccentricity, interaction count)
#
# Resources:
#
# 🧠 Deep LSTM Time-Series Forecasting Tutorial (TensorFlow)
#
# 📄 Towards Data Science: Feature Engineering for Time-Series
#
# 📘 Deep Learning with Python by François Chollet (Ch. 6–7)
#
# ---------------------------------------------------------------------------
#
# 🧪 D. Data Handling and Feature Engineering
# 1. Topics to Learn
# Processing raw simulation data (JSON, CSV, arrays)
#
# Calculating statistical features from orbital elements
#
# Labeling simulation outcomes: Define "stable" vs "unstable"
#
# Dimensionality reduction for visualization: PCA, t-SNE
#
# Resources:
#
# 📘 Feature Engineering Book by Alice Zheng
#
# 📄 Time Series Feature Extraction Library (TSFEL)
#
# 📄 t-SNE Explained Simply
#
# ---------------------------------------------------------------------------
#
# ✍️ E. Scientific Writing and Visualization
# 1. Topics to Study
# Writing scientific papers: structure, clarity, figures
#
# Creating orbital plots and feature importance charts
#
# Formatting in Overleaf using AASTeX or similar LaTeX templates
#
# Resources:
#
# 📝 Overleaf AASTeX Template for ApJ
#
# 🎓 How to Write a Scientific Paper – Nature Video
#
# 📄 Matplotlib Gallery
#
# Final Advice:
# Start by mastering the simulation and data processing parts, then move into ML modeling once your dataset is clean and labeled. If you're feeling overwhelmed, treat each phase as a mini-project and build incrementally.
